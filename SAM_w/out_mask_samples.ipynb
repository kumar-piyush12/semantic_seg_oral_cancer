# %% [markdown]
# <a href="https://colab.research.google.com/github/kumar-piyush12/semantic_seg_oral_cancer/blob/main/SAM_w/out_mask_samples.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# [![Roboflow Notebooks](https://media.roboflow.com/notebooks/template/bannertest2-2.png?ik-sdk-version=javascript-1.4.3&updatedAt=1672932710194)](https://github.com/roboflow/notebooks)
#
# # Segment Anything Model (SAM)
#
# ---
#
# [![GitHub](https://badges.aleen42.com/src/github.svg)](https://github.com/facebookresearch/segment-anything) [![arXiv](https://img.shields.io/badge/arXiv-2304.02643-b31b1b.svg)](https://arxiv.org/abs/2304.02643)
#
# Segment Anything Model (SAM): a new AI model from Meta AI that can "cut out" any object, in any image, with a single click. SAM is a promptable segmentation system with zero-shot generalization to unfamiliar objects and images, without the need for additional training. This notebook is an extension of the [official notebook](https://colab.research.google.com/github/facebookresearch/segment-anything/blob/main/notebooks/automatic_mask_generator_example.ipynb) prepared by Meta AI.
#
# ![segment anything model](https://media.roboflow.com/notebooks/examples/segment-anything-model-paper.png)
#
# ## Complementary Materials
#
# ---
#
# [![Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/roboflow-ai/notebooks/blob/main/notebooks/how-to-segment-anything-with-sam.ipynb) [![YouTube](https://badges.aleen42.com/src/youtube.svg)](https://youtu.be/D-D6ZmadzPE) [![Roboflow](https://raw.githubusercontent.com/roboflow-ai/notebooks/main/assets/badges/roboflow-blogpost.svg)](https://blog.roboflow.com/how-to-use-segment-anything-model-sam)
#
# We recommend that you follow along in this notebook while reading the blog post on Segment Anything Model.
#
# ![segment anything model blogpost](https://media.roboflow.com/notebooks/examples/segment-anything-model-blogpost.png)
#
# ## Pro Tip: Use GPU Acceleration
#
# If you are running this notebook in Google Colab, navigate to `Edit` -> `Notebook settings` -> `Hardware accelerator`, set it to `GPU`, and then click `Save`. This will ensure your notebook uses a GPU, which will significantly speed up model training times.
#
# ## Steps in this Tutorial
#
# In this tutorial, we are going to cover:
#
# - **Before you start** - Make sure you have access to the GPU
# - Install Segment Anything Model (SAM)
# - Download Example Data
# - Load Model
# - Automated Mask Generation
# - Generate Segmentation with Bounding Box
# - Segment Anything in Roboflow Universe Dataset
#
# ## Let's begin!

# %% [markdown]
# ## Before you start
#
# Let's make sure that we have access to GPU. We can use `nvidia-smi` command to do that. In case of any problems navigate to `Edit` -> `Notebook settings` -> `Hardware accelerator`, set it to `GPU`, and then click `Save`.

# %%
# !nvidia-smi
# Out:
# Wed Apr 16 16:24:19 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   60C    P8             11W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %% [markdown]
# **NOTE:** To make it easier for us to manage datasets, images and models we create a `HOME` constant.

# %%
import os
HOME = os.getcwd()
print("HOME:", HOME)
# Out:
# HOME: /content

# %% [markdown]
# ## Install Segment Anything Model (SAM) and other dependencies

# %%
# !pip install -q 'git+https://github.com/facebookresearch/segment-anything.git'
# Out:
#   Preparing metadata (setup.py) ... done
#   Building wheel for segment_anything (setup.py) ... done

# %%
# !pip install -q jupyter_bbox_widget roboflow dataclasses-json supervision==0.23.0
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 151.5/151.5 kB 9.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.2/85.2 kB 5.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 3.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 18.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 220.7/220.7 kB 14.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.9/50.9 kB 3.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 76.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 765.5/765.5 kB 36.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 32.3 MB/s eta 0:00:00

# %% [markdown]
# ### Download SAM weights

# %%
# !mkdir -p {HOME}/weights
# !wget -q https://dl.fbaipublicfiles.com/segment_anything/sam_vit_h_4b8939.pth -P {HOME}/weights

# %%
CHECKPOINT_PATH = os.path.join(HOME, "weights", "sam_vit_h_4b8939.pth")
print(CHECKPOINT_PATH, "; exist:", os.path.isfile(CHECKPOINT_PATH))
# Out:
# /content/weights/sam_vit_h_4b8939.pth ; exist: True

# %% [markdown]
# ## Mounting Google Drive: To access D3 images

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# List all files and folders in your Google Drive root directory
dataset_path = "/content/drive/My Drive/Oral Cancer Dataset"
print(os.listdir(dataset_path))
# Out:
# ['Annotation.json', 'Imagewise_Data.csv', 'Patientwise_Data.csv', 'Images.zip', 'Images', 'SAM_checkpoints', 'Healthy (1).csv', '.ipynb_checkpoints', 'Healthy.csv']

# %% [markdown]
# ## To extract Images.zip and access first 10 images

# %%
images_folder = "/content/drive/My Drive/Oral Cancer Dataset/Images/Images"
print(os.listdir(images_folder)[:10])  # Show first 10 extracted files
# Out:
# ['R-235-01.jpg', 'R-235-02.jpg', 'R-235-03.jpg', 'R-235-04.jpg', 'R-235-05.jpg', 'R-235-06.jpg', 'R-235-07.jpg', 'R-235-08.jpg', 'R-236-01.jpg', 'R-236-02.jpg']

# %% [markdown]
# ## Printing total number of images in D3

# %%
# Count number of files in the extracted images directory
num_images = len(os.listdir(images_folder))
print(num_images)
# Out:
# 3000

# %% [markdown]
# ## Load the SAM Model with GPU support

# %%
import os
import json
import cv2
import numpy as np
import matplotlib.pyplot as plt
import torch
from segment_anything import sam_model_registry, SamPredictor
from sklearn.metrics import jaccard_score, precision_score, recall_score

# Paths
CHECKPOINT_PATH = "/content/weights/sam_vit_h_4b8939.pth"
ANNOTATION_PATH = "/content/drive/MyDrive/Oral Cancer Dataset/Annotation.json"
IMAGE_FOLDER = "/content/drive/My Drive/Oral Cancer Dataset/Images/Images"

# Select model type and device
model_type = "vit_h"
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Load model and move it to GPU
sam = sam_model_registry[model_type](checkpoint=CHECKPOINT_PATH)
sam.to(device)

# Initialize predictor
predictor = SamPredictor(sam)

# %% [markdown]
# ## Ensuring GPU Usage

# %%
print(next(sam.parameters()).device)
# Out:
# cuda:0

# %% [markdown]
# ## Loading the annotations of images

# %%
with open(ANNOTATION_PATH, "r") as f:
    ann_data = json.load(f)

# Map image ID to file name
id_to_filename = {img["id"]: img["file_name"] for img in ann_data["images"]}

# %% [markdown]
# ## Polygon to Mask Function (Polygon information of lesions are given in Annotations.json)

# %%
def polygon_to_mask(polygon, img_shape):
    mask = np.zeros(img_shape, dtype=np.uint8)
    polygon = np.array(polygon).reshape((-1, 2)).astype(np.int32)
    cv2.fillPoly(mask, [polygon], color=1)
    return mask

# %% [markdown]
# ## Evaluation Metrics Design

# %%
def dice_score(gt, pred):
    intersection = np.sum(gt * pred)
    return (2. * intersection) / (np.sum(gt) + np.sum(pred) + 1e-7)

def evaluate(gt_mask, pred_mask):
    gt_flat = gt_mask.flatten()
    pred_flat = pred_mask.flatten()
    iou = jaccard_score(gt_flat, pred_flat)
    dice = dice_score(gt_mask, pred_mask)
    pixel_acc = np.mean(gt_flat == pred_flat)
    return iou, dice, pixel_acc

# %% [markdown]
# ## Loop Over Dataset and Evaluate: SAM generates mask based on Bounding Boxes annotations, finally they are crossed checked with "Polygon information" in .json. Thus, metrics are calculated.

# %%
#Paths to store progress safely in Google Drive
BASE_FOLDER = "/content/drive/MyDrive/Oral Cancer Dataset/SAM_checkpoints"
CHECKPOINT_PATH = os.path.join(BASE_FOLDER, "sam_checkpoint.json")

#Ensure the folder exists
os.makedirs(BASE_FOLDER, exist_ok=True)

# %%
#Load previous checkpoint (if it exists)
if os.path.exists(CHECKPOINT_PATH):
    with open(CHECKPOINT_PATH, "r") as f:
        checkpoint = json.load(f)
    processed_ids = set(checkpoint["processed_ids"])
    all_metrics = checkpoint["metrics"]
    print(f"🔄 Resuming from checkpoint. {len(processed_ids)} images already processed.")
else:
    processed_ids = set()
    all_metrics = []
    print("🆕 Starting fresh evaluation...")

skipped = 0
# Out:
# 🆕 Starting fresh evaluation...

# %%
#Load and format healthy image names (e.g., add '.jpg')
import pandas as pd
healthy_df = pd.read_csv('/content/drive/MyDrive/Oral Cancer Dataset/Healthy.csv')
healthy_images = set(name.strip() + ".jpg" for name in healthy_df['Image Name'].dropna())

# %%
healthy_df
# Out:
#     Image Name Category Clinical Diagnosis  Lesion Annotation Count
# 0      R-02-05  Healthy      Normal Mucosa                        0
# 1      R-02-06  Healthy      Normal Mucosa                        0
# 2      R-02-07  Healthy      Normal Mucosa                        0
# 3      R-02-08  Healthy      Normal Mucosa                        0
# 4      R-03-01  Healthy      Normal Mucosa                        0
# ..         ...      ...                ...                      ...
# 724   N-351-05  Healthy      Normal Mucosa                        0
# 725   N-351-06  Healthy      Normal Mucosa                        0
# 726   N-351-07  Healthy      Normal Mucosa                        0
# 727   N-351-08  Healthy      Normal Mucosa                        0
# 728   N-354-01  Healthy      Normal Mucosa                        0
#
# [729 rows x 4 columns]

# %%
#Loop through annotations and evaluate
for ann in ann_data["annotations"]:
    image_id = ann["image_id"]
    if image_id in processed_ids:
        continue  # Already processed

    image_name = id_to_filename[image_id]

    #Skip healthy images
    if image_name in healthy_images:
        print(f"⏭️ Skipping healthy image: {image_name}")
        skipped += 1
        continue

    image_path = os.path.join(IMAGE_FOLDER, image_name)

    #Load image
    image = cv2.imread(image_path)
    if image is None:
        print(f"❌ Image not found or unreadable: {image_path}")
        skipped += 1
        continue

    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    predictor.set_image(image)

    # Bounding box as SAM prompt
    x, y, w, h = ann["bbox"]
    bbox = np.array([x, y, x + w, y + h])

    # Predict mask using SAM
    masks, _, _ = predictor.predict(box=bbox, multimask_output=False)
    pred_mask = masks[0].astype(np.uint8)

    # Ground truth from polygon segmentation
    gt_mask = polygon_to_mask(ann["segmentation"], image.shape[:2])
    if pred_mask.shape != gt_mask.shape:
        pred_mask = cv2.resize(pred_mask, (gt_mask.shape[1], gt_mask.shape[0]))

    # Evaluate metrics
    iou, dice, acc = evaluate(gt_mask, pred_mask)

    # Store metrics
    all_metrics.append({
        "image_id": image_id,
        "image_name": image_name,
        "iou": iou,
        "dice": dice,
        "accuracy": acc
    })
    processed_ids.add(image_id)

    #Save progress (checkpoint)
    with open(CHECKPOINT_PATH, "w") as f:
        json.dump({
            "processed_ids": list(processed_ids),
            "metrics": all_metrics
        }, f)

    #Visualize results
    fig, axs = plt.subplots(1, 3, figsize=(18, 6))

    axs[0].imshow(image)
    axs[0].set_title(f"Original Image\n{image_name}")
    axs[0].axis('off')

    axs[1].imshow(image)
    axs[1].imshow(pred_mask, alpha=0.5, cmap='jet')
    axs[1].set_title(f"SAM Predicted Mask\nIoU: {iou:.4f}")
    axs[1].axis('off')

    axs[2].imshow(image)
    axs[2].imshow(gt_mask, alpha=0.5, cmap='gray')
    axs[2].set_title(f"Ground Truth Mask\nDice: {dice:.4f}")
    axs[2].axis('off')

    plt.suptitle(f"Pixel Accuracy: {acc:.4f}", fontsize=14, y=1.05)
    plt.tight_layout()
    plt.show()

    print(f"✅ Processed: {image_name} | IoU: {iou:.4f}, Dice: {dice:.4f}, Acc: {acc:.4f}")

# %% [markdown]
# ## Restarting from checkpoints (saved in sam_checkpoints.json) due to Collab's Memory Runout

# %%
#Load previous checkpoint (if it exists)
if os.path.exists(CHECKPOINT_PATH):
    with open(CHECKPOINT_PATH, "r") as f:
        checkpoint = json.load(f)
    processed_ids = set(checkpoint["processed_ids"])
    all_metrics = checkpoint["metrics"]
    print(f"🔄 Resuming from checkpoint. {len(processed_ids)} images already processed.")
else:
    processed_ids = set()
    all_metrics = []
    print("🆕 Starting fresh evaluation...")

skipped = 0
# Out:
# 🔄 Resuming from checkpoint. 1383 images already processed.

# %%
#Loop through annotations and evaluate
for ann in ann_data["annotations"]:
    image_id = ann["image_id"]
    if image_id in processed_ids:
        continue  # Already processed

    image_name = id_to_filename[image_id]

    #Skip healthy images
    if image_name in healthy_images:
        print(f"⏭️ Skipping healthy image: {image_name}")
        skipped += 1
        continue

    image_path = os.path.join(IMAGE_FOLDER, image_name)

    #Load image
    image = cv2.imread(image_path)
    if image is None:
        print(f"❌ Image not found or unreadable: {image_path}")
        skipped += 1
        continue

    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    predictor.set_image(image)  # <-- Make sure predictor is initialized earlier

    # Bounding box as SAM prompt
    x, y, w, h = ann["bbox"]
    bbox = np.array([x, y, x + w, y + h])

    # Predict mask using SAM
    masks, _, _ = predictor.predict(box=bbox, multimask_output=False)
    pred_mask = masks[0].astype(np.uint8)

    # Ground truth from polygon segmentation
    gt_mask = polygon_to_mask(ann["segmentation"], image.shape[:2])  # <-- define this elsewhere
    if pred_mask.shape != gt_mask.shape:
        pred_mask = cv2.resize(pred_mask, (gt_mask.shape[1], gt_mask.shape[0]))

    # Evaluate metrics
    iou, dice, acc = evaluate(gt_mask, pred_mask)  # <-- define this elsewhere

    # Store metrics
    all_metrics.append({
        "image_id": image_id,
        "image_name": image_name,
        "iou": iou,
        "dice": dice,
        "accuracy": acc
    })
    processed_ids.add(image_id)

    #Save progress (checkpoint)
    with open(CHECKPOINT_PATH, "w") as f:
        json.dump({
            "processed_ids": list(processed_ids),
            "metrics": all_metrics
        }, f)

    #Visualize results
    fig, axs = plt.subplots(1, 3, figsize=(18, 6))

    axs[0].imshow(image)
    axs[0].set_title(f"Original Image\n{image_name}")
    axs[0].axis('off')

    axs[1].imshow(image)
    axs[1].imshow(pred_mask, alpha=0.5, cmap='jet')
    axs[1].set_title(f"SAM Predicted Mask\nIoU: {iou:.4f}")
    axs[1].axis('off')

    axs[2].imshow(image)
    axs[2].imshow(gt_mask, alpha=0.5, cmap='gray')
    axs[2].set_title(f"Ground Truth Mask\nDice: {dice:.4f}")
    axs[2].axis('off')

    plt.suptitle(f"Pixel Accuracy: {acc:.4f}", fontsize=14, y=1.05)
    plt.tight_layout()
    plt.show()

    print(f"✅ Processed: {image_name} | IoU: {iou:.4f}, Dice: {dice:.4f}, Acc: {acc:.4f}")

# %% [markdown]
# ##Checking whether all 3000 images have been considered or not?
# (Cancerous: 2271, Healthy: 729)

# %%
#Load previous checkpoint (if it exists)
if os.path.exists(CHECKPOINT_PATH):
    with open(CHECKPOINT_PATH, "r") as f:
        checkpoint = json.load(f)
    processed_ids = set(checkpoint["processed_ids"])
    all_metrics = checkpoint["metrics"]
    print(f"{len(processed_ids)} images already processed.")
# Out:
# 2271 images already processed.

# %%
#Loop through annotations and evaluate
skipped = 0
for ann in ann_data["annotations"]:
    image_id = ann["image_id"]
    if image_id in processed_ids:
        continue  # Already processed

    image_name = id_to_filename[image_id]

    #Skip healthy images
    if image_name in healthy_images:
        print(f"⏭️ Skipping healthy image: {image_name}")
        skipped += 1
        continue

print(f'No. of Healthy images, which were skipped for mask formation by SAM model: {skipped}')
# Out:
# ⏭️ Skipping healthy image: R-02-05.jpg
# ⏭️ Skipping healthy image: R-02-06.jpg
# ⏭️ Skipping healthy image: R-02-07.jpg
# ⏭️ Skipping healthy image: R-02-08.jpg
# ⏭️ Skipping healthy image: R-03-01.jpg
# ⏭️ Skipping healthy image: R-03-05.jpg
# ⏭️ Skipping healthy image: R-04-03.jpg
# ⏭️ Skipping healthy image: R-04-04.jpg
# ⏭️ Skipping healthy image: R-04-05.jpg
# ⏭️ Skipping healthy image: R-06-04.jpg
# ⏭️ Skipping healthy image: R-06-05.jpg
# ⏭️ Skipping healthy image: R-06-06.jpg
# ⏭️ Skipping healthy image: R-06-07.jpg
# ⏭️ Skipping healthy image: R-07-01.jpg
# ⏭️ Skipping healthy image: R-07-02.jpg
# ⏭️ Skipping healthy image: R-07-03.jpg
# ⏭️ Skipping healthy image: R-07-04.jpg
# ⏭️ Skipping healthy image: R-07-05.jpg
# ⏭️ Skipping healthy image: R-08-06.jpg
# ⏭️ Skipping healthy image: R-13-02.jpg
# ⏭️ Skipping healthy image: R-14-02.jpg
# ⏭️ Skipping healthy image: R-14-03.jpg
# ⏭️ Skipping healthy image: R-14-04.jpg
# ⏭️ Skipping healthy image: R-14-05.jpg
# ⏭️ Skipping healthy image: R-15-04.jpg
# ⏭️ Skipping healthy image: R-23-02.jpg
# ⏭️ Skipping healthy image: R-26-02.jpg
# ⏭️ Skipping healthy image: R-26-04.jpg
# ⏭️ Skipping healthy image: R-29-02.jpg
# ⏭️ Skipping healthy image: R-32-02.jpg
# ⏭️ Skipping healthy image: R-35-04.jpg
# ⏭️ Skipping healthy image: R-36-05.jpg
# ⏭️ Skipping healthy image: R-37-04.jpg
# ⏭️ Skipping healthy image: R-39-02.jpg
# ⏭️ Skipping healthy image: R-39-03.jpg
# ⏭️ Skipping healthy image: R-39-04.jpg
# ⏭️ Skipping healthy image: R-39-05.jpg
# ⏭️ Skipping healthy image: R-40-03.jpg
# ⏭️ Skipping healthy image: R-41-01.jpg
# ⏭️ Skipping healthy image: R-41-02.jpg
# ⏭️ Skipping healthy image: R-41-03.jpg
# ⏭️ Skipping healthy image: R-41-04.jpg
# ⏭️ Skipping healthy image: R-44-01.jpg
# ⏭️ Skipping healthy image: R-44-05.jpg
# ⏭️ Skipping healthy image: R-44-06.jpg
# ⏭️ Skipping healthy image: R-44-07.jpg
# ⏭️ Skipping healthy image: R-46-02.jpg
# ⏭️ Skipping healthy image: R-46-03.jpg
# ⏭️ Skipping healthy image: R-46-04.jpg
# ⏭️ Skipping healthy image: R-46-05.jpg
# ⏭️ Skipping healthy image: R-47-04.jpg
# ⏭️ Skipping healthy image: R-47-05.jpg
# ⏭️ Skipping healthy image: R-47-06.jpg
# ⏭️ Skipping healthy image: R-47-07.jpg
# ⏭️ Skipping healthy image: R-48-01.jpg
# ⏭️ Skipping healthy image: R-48-02.jpg
# ⏭️ Skipping healthy image: R-48-03.jpg
# ⏭️ Skipping healthy image: R-48-04.jpg
# ⏭️ Skipping healthy image: R-51-05.jpg
# ⏭️ Skipping healthy image: R-51-06.jpg
# ⏭️ Skipping healthy image: R-54-01.jpg
# ⏭️ Skipping healthy image: R-54-03.jpg
# ⏭️ Skipping healthy image: R-54-04.jpg
# ⏭️ Skipping healthy image: R-60-01.jpg
# ⏭️ Skipping healthy image: R-60-02.jpg
# ⏭️ Skipping healthy image: R-60-04.jpg
# ⏭️ Skipping healthy image: R-61-03.jpg
# ⏭️ Skipping healthy image: R-61-04.jpg
# ⏭️ Skipping healthy image: R-61-05.jpg
# ⏭️ Skipping healthy image: R-62-02.jpg
# ⏭️ Skipping healthy image: R-62-03.jpg
# ⏭️ Skipping healthy image: R-62-04.jpg
# ⏭️ Skipping healthy image: R-66-02.jpg
# ⏭️ Skipping healthy image: R-67-01.jpg
# ⏭️ Skipping healthy image: R-67-07.jpg
# ⏭️ Skipping healthy image: R-68-02.jpg
# ⏭️ Skipping healthy image: R-69-01.jpg
# ⏭️ Skipping healthy image: R-69-02.jpg
# ⏭️ Skipping healthy image: R-69-03.jpg
# ⏭️ Skipping healthy image: R-70-02.jpg
# ⏭️ Skipping healthy image: R-70-03.jpg
# ⏭️ Skipping healthy image: R-70-04.jpg
# ⏭️ Skipping healthy image: R-70-05.jpg
# ⏭️ Skipping healthy image: R-73-01.jpg
# ⏭️ Skipping healthy image: R-73-02.jpg
# ⏭️ Skipping healthy image: R-73-03.jpg
# ⏭️ Skipping healthy image: R-73-04.jpg
# ⏭️ Skipping healthy image: R-74-03.jpg
# ⏭️ Skipping healthy image: R-74-04.jpg
# ⏭️ Skipping healthy image: R-75-02.jpg
# ⏭️ Skipping healthy image: R-75-03.jpg
# ⏭️ Skipping healthy image: R-75-04.jpg
# ⏭️ Skipping healthy image: R-75-05.jpg
# ⏭️ Skipping healthy image: R-80-01.jpg
# ⏭️ Skipping healthy image: R-80-02.jpg
# ⏭️ Skipping healthy image: R-80-03.jpg
# ⏭️ Skipping healthy image: R-86-06.jpg
# ⏭️ Skipping healthy image: R-88-03.jpg
# ⏭️ Skipping healthy image: R-88-04.jpg
# ⏭️ Skipping healthy image: R-91-01.jpg
# ⏭️ Skipping healthy image: R-91-02.jpg
# ⏭️ Skipping healthy image: R-91-03.jpg
# ⏭️ Skipping healthy image: R-95-02.jpg
# ⏭️ Skipping healthy image: R-95-03.jpg
# ⏭️ Skipping healthy image: R-95-04.jpg
# ⏭️ Skipping healthy image: R-95-05.jpg
# ⏭️ Skipping healthy image: R-96-05.jpg
# ⏭️ Skipping healthy image: R-102-02.jpg
# ⏭️ Skipping healthy image: R-102-03.jpg
# ⏭️ Skipping healthy image: R-102-04.jpg
# ⏭️ Skipping healthy image: R-103-02.jpg
# ⏭️ Skipping healthy image: R-103-03.jpg
# ⏭️ Skipping healthy image: R-105-07.jpg
# ⏭️ Skipping healthy image: R-105-08.jpg
# ⏭️ Skipping healthy image: N-128-01.jpg
# ⏭️ Skipping healthy image: N-128-02.jpg
# ⏭️ Skipping healthy image: N-128-03.jpg
# ⏭️ Skipping healthy image: N-128-04.jpg
# ⏭️ Skipping healthy image: N-131-01.jpg
# ⏭️ Skipping healthy image: N-131-02.jpg
# ⏭️ Skipping healthy image: N-135-01.jpg
# ⏭️ Skipping healthy image: N-135-02.jpg
# ⏭️ Skipping healthy image: N-136-02.jpg
# ⏭️ Skipping healthy image: N-141-02.jpg
# ⏭️ Skipping healthy image: N-141-03.jpg
# ⏭️ Skipping healthy image: N-148-01.jpg
# ⏭️ Skipping healthy image: N-156-01.jpg
# ⏭️ Skipping healthy image: N-156-02.jpg
# ⏭️ Skipping healthy image: N-164-04.jpg
# ⏭️ Skipping healthy image: N-170-03.jpg
# ⏭️ Skipping healthy image: N-173-04.jpg
# ⏭️ Skipping healthy image: N-174-01.jpg
# ⏭️ Skipping healthy image: N-174-03.jpg
# ⏭️ Skipping healthy image: N-176-03.jpg
# ⏭️ Skipping healthy image: N-184-02.jpg
# ⏭️ Skipping healthy image: N-184-03.jpg
# ⏭️ Skipping healthy image: N-189-02.jpg
# ⏭️ Skipping healthy image: N-192-03.jpg
# ⏭️ Skipping healthy image: N-193-03.jpg
# ⏭️ Skipping healthy image: N-193-05.jpg
# ⏭️ Skipping healthy image: N-199-04.jpg
# ⏭️ Skipping healthy image: N-206-02.jpg
# ⏭️ Skipping healthy image: N-206-03.jpg
# ⏭️ Skipping healthy image: N-206-04.jpg
# ⏭️ Skipping healthy image: N-206-05.jpg
# ⏭️ Skipping healthy image: N-210-02.jpg
# ⏭️ Skipping healthy image: N-215-03.jpg
# ⏭️ Skipping healthy image: N-218-02.jpg
# ⏭️ Skipping healthy image: N-221-02.jpg
# ⏭️ Skipping healthy image: N-223-02.jpg
# ⏭️ Skipping healthy image: N-238-02.jpg
# ⏭️ Skipping healthy image: N-238-03.jpg
# ⏭️ Skipping healthy image: N-238-04.jpg
# ⏭️ Skipping healthy image: N-241-05.jpg
# ⏭️ Skipping healthy image: N-242-03.jpg
# ⏭️ Skipping healthy image: N-242-04.jpg
# ⏭️ Skipping healthy image: N-245-04.jpg
# ⏭️ Skipping healthy image: N-248-04.jpg
# ⏭️ Skipping healthy image: N-251-02.jpg
# ⏭️ Skipping healthy image: N-251-03.jpg
# ⏭️ Skipping healthy image: N-251-04.jpg
# ⏭️ Skipping healthy image: K-001-01.jpg
# ⏭️ Skipping healthy image: K-001-02.jpg
# ⏭️ Skipping healthy image: K-003-03.jpg
# ⏭️ Skipping healthy image: K-003-04.jpg
# ⏭️ Skipping healthy image: K-003-05.jpg
# ⏭️ Skipping healthy image: K-006-05.jpg
# ⏭️ Skipping healthy image: K-010-03.jpg
# ⏭️ Skipping healthy image: K-010-04.jpg
# ⏭️ Skipping healthy image: K-016-02.jpg
# ⏭️ Skipping healthy image: K-020-03.jpg
# ⏭️ Skipping healthy image: K-024-02.jpg
# ⏭️ Skipping healthy image: K-028-01.jpg
# ⏭️ Skipping healthy image: K-028-03.jpg
# ⏭️ Skipping healthy image: K-028-04.jpg
# ⏭️ Skipping healthy image: S-10-04.jpg
# ⏭️ Skipping healthy image: S-26-02.jpg
# ⏭️ Skipping healthy image: S-26-03.jpg
# ⏭️ Skipping healthy image: S-26-04.jpg
# ⏭️ Skipping healthy image: S-27-04.jpg
# ⏭️ Skipping healthy image: S-27-05.jpg
# ⏭️ Skipping healthy image: S-27-06.jpg
# ⏭️ Skipping healthy image: S-28-01.jpg
# ⏭️ Skipping healthy image: S-28-02.jpg
# ⏭️ Skipping healthy image: S-28-04.jpg
# ⏭️ Skipping healthy image: S-29-01.jpg
# ⏭️ Skipping healthy image: S-29-02.jpg
# ⏭️ Skipping healthy image: S-29-04.jpg
# ⏭️ Skipping healthy image: S-29-05.jpg
# ⏭️ Skipping healthy image: S-38-02.jpg
# ⏭️ Skipping healthy image: S-42-01.jpg
# ⏭️ Skipping healthy image: S-43-01.jpg
# ⏭️ Skipping healthy image: S-47-03.jpg
# ⏭️ Skipping healthy image: S-49-02.jpg
# ⏭️ Skipping healthy image: S-62-04.jpg
# ⏭️ Skipping healthy image: S-67-01.jpg
# ⏭️ Skipping healthy image: S-67-02.jpg
# ⏭️ Skipping healthy image: S-70-01.jpg
# ⏭️ Skipping healthy image: S-70-02.jpg
# ⏭️ Skipping healthy image: S-70-03.jpg
# ⏭️ Skipping healthy image: S-70-04.jpg
# ⏭️ Skipping healthy image: S-71-01.jpg
# ⏭️ Skipping healthy image: S-75-03.jpg
# ⏭️ Skipping healthy image: S-75-04.jpg
# ⏭️ Skipping healthy image: S-76-03.jpg
# ⏭️ Skipping healthy image: S-79-04.jpg
# ⏭️ Skipping healthy image: S-89-02.jpg
# ⏭️ Skipping healthy image: S-96-02.jpg
# ⏭️ Skipping healthy image: S-96-04.jpg
# ⏭️ Skipping healthy image: S-99-03.jpg
# ⏭️ Skipping healthy image: S-104-01.jpg
# ⏭️ Skipping healthy image: S-107-02.jpg
# ⏭️ Skipping healthy image: S-107-04.jpg
# ⏭️ Skipping healthy image: S-108-03.jpg
# ⏭️ Skipping healthy image: S-127-01.jpg
# ⏭️ Skipping healthy image: S-128-06.jpg
# ⏭️ Skipping healthy image: S-131-01.jpg
# ⏭️ Skipping healthy image: S-137-03.jpg
# ⏭️ Skipping healthy image: S-141-05.jpg
# ⏭️ Skipping healthy image: S-144-02.jpg
# ⏭️ Skipping healthy image: S-144-03.jpg
# ⏭️ Skipping healthy image: S-149-02.jpg
# ⏭️ Skipping healthy image: S-151-04.jpg
# ⏭️ Skipping healthy image: S-153-02.jpg
# ⏭️ Skipping healthy image: S-154-01.jpg
# ⏭️ Skipping healthy image: S-154-02.jpg
# ⏭️ Skipping healthy image: S-154-03.jpg
# ⏭️ Skipping healthy image: S-154-06.jpg
# ⏭️ Skipping healthy image: S-157-05.jpg
# ⏭️ Skipping healthy image: S-159-02.jpg
# ⏭️ Skipping healthy image: S-170-01.jpg
# ⏭️ Skipping healthy image: N-098-01.jpg
# ⏭️ Skipping healthy image: N-098-03.jpg
# ⏭️ Skipping healthy image: N-113-01.jpg
# ⏭️ Skipping healthy image: S-45-04.jpg
# ⏭️ Skipping healthy image: C-10-12-5.jpg
# ⏭️ Skipping healthy image: C-10-2-7.jpg
# ⏭️ Skipping healthy image: C-10-3-6.jpg
# ⏭️ Skipping healthy image: C-10-4-3.jpg
# ⏭️ Skipping healthy image: C-10-5-4.jpg
# ⏭️ Skipping healthy image: C-10-6-2.jpg
# ⏭️ Skipping healthy image: C-10-7-1.jpg
# ⏭️ Skipping healthy image: C-11-12-6.jpg
# ⏭️ Skipping healthy image: C-11-4-1.jpg
# ⏭️ Skipping healthy image: C-11-5-2.jpg
# ⏭️ Skipping healthy image: C-11-6-3.jpg
# ⏭️ Skipping healthy image: C-11-6-4.jpg
# ⏭️ Skipping healthy image: C-11-7-5.jpg
# ⏭️ Skipping healthy image: C-12-4-3.jpg
# ⏭️ Skipping healthy image: C-12-5-4.jpg
# ⏭️ Skipping healthy image: C-12-6-1.jpg
# ⏭️ Skipping healthy image: C-12-7-2.jpg
# ⏭️ Skipping healthy image: C-12-9-5.jpg
# ⏭️ Skipping healthy image: C-13-4-4.jpg
# ⏭️ Skipping healthy image: C-13-4-5.jpg
# ⏭️ Skipping healthy image: C-13-6-1.jpg
# ⏭️ Skipping healthy image: C-13-6-2.jpg
# ⏭️ Skipping healthy image: C-13-6-3.jpg
# ⏭️ Skipping healthy image: C-13-6-8.jpg
# ⏭️ Skipping healthy image: C-13-7-6.jpg
# ⏭️ Skipping healthy image: C-13-7-7.jpg
# ⏭️ Skipping healthy image: C-14-4-1.jpg
# ⏭️ Skipping healthy image: C-14-5-3.jpg
# ⏭️ Skipping healthy image: C-14-5-4.jpg
# ⏭️ Skipping healthy image: C-14-7-2.jpg
# ⏭️ Skipping healthy image: C-14-7-5.jpg
# ⏭️ Skipping healthy image: C-14-7-6.jpg
# ⏭️ Skipping healthy image: C-15-12-7.jpg
# ⏭️ Skipping healthy image: C-15-12-8.jpg
# ⏭️ Skipping healthy image: C-15-4-3.jpg
# ⏭️ Skipping healthy image: C-15-5-4.jpg
# ⏭️ Skipping healthy image: C-15-5-5.jpg
# ⏭️ Skipping healthy image: C-15-6-1.jpg
# ⏭️ Skipping healthy image: C-15-6-2.jpg
# ⏭️ Skipping healthy image: C-15-7-6.jpg
# ⏭️ Skipping healthy image: C-16-4-2.jpg
# ⏭️ Skipping healthy image: C-16-6-1.jpg
# ⏭️ Skipping healthy image: C-16-7-3.jpg
# ⏭️ Skipping healthy image: C-16-7-4.jpg
# ⏭️ Skipping healthy image: C-17-4-1.jpg
# ⏭️ Skipping healthy image: C-17-5-5.jpg
# ⏭️ Skipping healthy image: C-17-6-2.jpg
# ⏭️ Skipping healthy image: C-17-7-3.jpg
# ⏭️ Skipping healthy image: C-17-7-4.jpg
# ⏭️ Skipping healthy image: C-18-12-2.jpg
# ⏭️ Skipping healthy image: C-18-5-4.jpg
# ⏭️ Skipping healthy image: C-18-7-1.jpg
# ⏭️ Skipping healthy image: C-18-7-3.jpg
# ⏭️ Skipping healthy image: C-20-5-5.jpg
# ⏭️ Skipping healthy image: C-20-6-3.jpg
# ⏭️ Skipping healthy image: C-20-6-4.jpg
# ⏭️ Skipping healthy image: C-20-6-6.jpg
# ⏭️ Skipping healthy image: C-20-7-1.jpg
# ⏭️ Skipping healthy image: C-20-7-2.jpg
# ⏭️ Skipping healthy image: C-20-8-7.jpg
# ⏭️ Skipping healthy image: C-20-8-8.jpg
# ⏭️ Skipping healthy image: C-21-4-4.jpg
# ⏭️ Skipping healthy image: C-21-7-1.jpg
# ⏭️ Skipping healthy image: C-21-7-5.jpg
# ⏭️ Skipping healthy image: C-21-9-2.jpg
# ⏭️ Skipping healthy image: C-21-9-3.jpg
# ⏭️ Skipping healthy image: C-22-4-5.jpg
# ⏭️ Skipping healthy image: C-22-5-6.jpg
# ⏭️ Skipping healthy image: C-22-5-7.jpg
# ⏭️ Skipping healthy image: C-22-6-3.jpg
# ⏭️ Skipping healthy image: C-22-6-4.jpg
# ⏭️ Skipping healthy image: C-22-6-8.jpg
# ⏭️ Skipping healthy image: C-22-7-1.jpg
# ⏭️ Skipping healthy image: C-22-7-2.jpg
# ⏭️ Skipping healthy image: C-22-8-9.jpg
# ⏭️ Skipping healthy image: C-23-4-1.jpg
# ⏭️ Skipping healthy image: C-23-4-2.jpg
# ⏭️ Skipping healthy image: C-23-5-3.jpg
# ⏭️ Skipping healthy image: C-23-5-4.jpg
# ⏭️ Skipping healthy image: C-23-6-5.jpg
# ⏭️ Skipping healthy image: C-23-7-6.jpg
# ⏭️ Skipping healthy image: C-24-1-1.jpg
# ⏭️ Skipping healthy image: C-24-1-2.jpg
# ⏭️ Skipping healthy image: C-24-1-7.jpg
# ⏭️ Skipping healthy image: C-24-4-3.jpg
# ⏭️ Skipping healthy image: C-24-5-4.jpg
# ⏭️ Skipping healthy image: C-24-6-8.jpg
# ⏭️ Skipping healthy image: C-24-6-9.jpg
# ⏭️ Skipping healthy image: C-24-7-5.jpg
# ⏭️ Skipping healthy image: C-24-7-6.jpg
# ⏭️ Skipping healthy image: C-25-8-6.jpg
# ⏭️ Skipping healthy image: C-27-4-2.jpg
# ⏭️ Skipping healthy image: C-27-5-4.jpg
# ⏭️ Skipping healthy image: C-27-7-1.jpg
# ⏭️ Skipping healthy image: C-27-7-3.jpg
# ⏭️ Skipping healthy image: C-27-7-5.jpg
# ⏭️ Skipping healthy image: C-28-4-2.jpg
# ⏭️ Skipping healthy image: C-28-5-3.jpg
# ⏭️ Skipping healthy image: C-28-6-4.jpg
# ⏭️ Skipping healthy image: C-28-7-1.jpg
# ⏭️ Skipping healthy image: C-28-7-5.jpg
# ⏭️ Skipping healthy image: C-29-1-2.jpg
# ⏭️ Skipping healthy image: C-29-4-3.jpg
# ⏭️ Skipping healthy image: C-29-4-5.jpg
# ⏭️ Skipping healthy image: C-29-5-4.jpg
# ⏭️ Skipping healthy image: C-29-5-6.jpg
# ⏭️ Skipping healthy image: C-29-6-8.jpg
# ⏭️ Skipping healthy image: C-29-6-9.jpg
# ⏭️ Skipping healthy image: C-29-7-1.jpg
# ⏭️ Skipping healthy image: C-29-7-7.jpg
# ⏭️ Skipping healthy image: C-29-8-10.jpg
# ⏭️ Skipping healthy image: C-30-5-2.jpg
# ⏭️ Skipping healthy image: C-30-6-1.jpg
# ⏭️ Skipping healthy image: C-30-6-3.jpg
# ⏭️ Skipping healthy image: C-32-4-2.jpg
# ⏭️ Skipping healthy image: C-32-5-3.jpg
# ⏭️ Skipping healthy image: C-32-6-5.jpg
# ⏭️ Skipping healthy image: C-32-7-1.jpg
# ⏭️ Skipping healthy image: C-32-7-4.jpg
# ⏭️ Skipping healthy image: C-32-8-6.jpg
# ⏭️ Skipping healthy image: C-33-4-3.jpg
# ⏭️ Skipping healthy image: C-33-5-4.jpg
# ⏭️ Skipping healthy image: C-33-6-5.jpg
# ⏭️ Skipping healthy image: C-33-7-1.jpg
# ⏭️ Skipping healthy image: C-33-7-2.jpg
# ⏭️ Skipping healthy image: C-33-8-6.jpg
# ⏭️ Skipping healthy image: C-33-8-7.jpg
# ⏭️ Skipping healthy image: C-34-4-4.jpg
# ⏭️ Skipping healthy image: C-34-5-2.jpg
# ⏭️ Skipping healthy image: C-34-5-5.jpg
# ⏭️ Skipping healthy image: C-34-7-1.jpg
# ⏭️ Skipping healthy image: C-34-9-3.jpg
# ⏭️ Skipping healthy image: C-35-6-2.jpg
# ⏭️ Skipping healthy image: C-35-6-3.jpg
# ⏭️ Skipping healthy image: C-35-7-1.jpg
# ⏭️ Skipping healthy image: C-36-1-1.jpg
# ⏭️ Skipping healthy image: C-36-1-3.jpg
# ⏭️ Skipping healthy image: C-3-6-1.jpg
# ⏭️ Skipping healthy image: C-36-4-6.jpg
# ⏭️ Skipping healthy image: C-36-5-7.jpg
# ⏭️ Skipping healthy image: C-36-6-2.jpg
# ⏭️ Skipping healthy image: C-36-7-4.jpg
# ⏭️ Skipping healthy image: C-36-7-5.jpg
# ⏭️ Skipping healthy image: C-36-8-8.jpg
# ⏭️ Skipping healthy image: C-3-7-3.jpg
# ⏭️ Skipping healthy image: C-37-8-8.jpg
# ⏭️ Skipping healthy image: C-38-1-1.jpg
# ⏭️ Skipping healthy image: C-38-4-4.jpg
# ⏭️ Skipping healthy image: C-38-5-5.jpg
# ⏭️ Skipping healthy image: C-38-5-6.jpg
# ⏭️ Skipping healthy image: C-38-7-2.jpg
# ⏭️ Skipping healthy image: C-38-7-7.jpg
# ⏭️ Skipping healthy image: C-38-7-8.jpg
# ⏭️ Skipping healthy image: C-38-8-3.jpg
# ⏭️ Skipping healthy image: C-39-1-1.jpg
# ⏭️ Skipping healthy image: C-3-9-2.jpg
# ⏭️ Skipping healthy image: C-39-4-3.jpg
# ⏭️ Skipping healthy image: C-3-9-4.jpg
# ⏭️ Skipping healthy image: C-39-5-4.jpg
# ⏭️ Skipping healthy image: C-39-5-5.jpg
# ⏭️ Skipping healthy image: C-39-6-6.jpg
# ⏭️ Skipping healthy image: C-39-7-7.jpg
# ⏭️ Skipping healthy image: C-39-9-2.jpg
# ⏭️ Skipping healthy image: C-40-1-1.jpg
# ⏭️ Skipping healthy image: C-40-4-5.jpg
# ⏭️ Skipping healthy image: C-40-6-4.jpg
# ⏭️ Skipping healthy image: C-40-7-2.jpg
# ⏭️ Skipping healthy image: C-40-7-3.jpg
# ⏭️ Skipping healthy image: C-41-1-1.jpg
# ⏭️ Skipping healthy image: C-41-4-5.jpg
# ⏭️ Skipping healthy image: C-41-5-6.jpg
# ⏭️ Skipping healthy image: C-41-6-4.jpg
# ⏭️ Skipping healthy image: C-41-6-9.jpg
# ⏭️ Skipping healthy image: C-41-7-2.jpg
# ⏭️ Skipping healthy image: C-41-7-3.jpg
# ⏭️ Skipping healthy image: C-41-8-7.jpg
# ⏭️ Skipping healthy image: C-41-8-8.jpg
# ⏭️ Skipping healthy image: C-42-5-5.jpg
# ⏭️ Skipping healthy image: C-42-6-7.jpg
# ⏭️ Skipping healthy image: C-42-7-2.jpg
# ⏭️ Skipping healthy image: C-42-7-3.jpg
# ⏭️ Skipping healthy image: C-42-8-8.jpg
# ⏭️ Skipping healthy image: C-43-1-1.jpg
# ⏭️ Skipping healthy image: C-43-1-2.jpg
# ⏭️ Skipping healthy image: C-43-4-6.jpg
# ⏭️ Skipping healthy image: C-43-5-7.jpg
# ⏭️ Skipping healthy image: C-43-6-4.jpg
# ⏭️ Skipping healthy image: C-43-6-5.jpg
# ⏭️ Skipping healthy image: C-43-7-3.jpg
# ⏭️ Skipping healthy image: C-43-7-8.jpg
# ⏭️ Skipping healthy image: C-43-8-9.jpg
# ⏭️ Skipping healthy image: C-44-1-1.jpg
# ⏭️ Skipping healthy image: C-44-4-4.jpg
# ⏭️ Skipping healthy image: C-44-5-5.jpg
# ⏭️ Skipping healthy image: C-44-6-2.jpg
# ⏭️ Skipping healthy image: C-44-6-3.jpg
# ⏭️ Skipping healthy image: C-44-8-7.jpg
# ⏭️ Skipping healthy image: C-45-1-1.jpg
# ⏭️ Skipping healthy image: C-45-4-4.jpg
# ⏭️ Skipping healthy image: C-45-5-5.jpg
# ⏭️ Skipping healthy image: C-45-6-2.jpg
# ⏭️ Skipping healthy image: C-45-6-3.jpg
# ⏭️ Skipping healthy image: C-45-7-6.jpg
# ⏭️ Skipping healthy image: C-45-8-7.jpg
# ⏭️ Skipping healthy image: C-46-1-1.jpg
# ⏭️ Skipping healthy image: C-46-1-2.jpg
# ⏭️ Skipping healthy image: C-4-6-1.jpg
# ⏭️ Skipping healthy image: C-4-6-2.jpg
# ⏭️ Skipping healthy image: C-46-4-4.jpg
# ⏭️ Skipping healthy image: C-46-5-5.jpg
# ⏭️ Skipping healthy image: C-46-6-6.jpg
# ⏭️ Skipping healthy image: C-46-6-7.jpg
# ⏭️ Skipping healthy image: C-46-7-3.jpg
# ⏭️ Skipping healthy image: C-46-8-8.jpg
# ⏭️ Skipping healthy image: C-47-1-1.jpg
# ⏭️ Skipping healthy image: C-4-7-4.jpg
# ⏭️ Skipping healthy image: C-47-5-3.jpg
# ⏭️ Skipping healthy image: C-47-5-4.jpg
# ⏭️ Skipping healthy image: C-47-6-6.jpg
# ⏭️ Skipping healthy image: C-47-7-2.jpg
# ⏭️ Skipping healthy image: C-47-7-5.jpg
# ⏭️ Skipping healthy image: C-48-1-2.jpg
# ⏭️ Skipping healthy image: C-48-4-5.jpg
# ⏭️ Skipping healthy image: C-48-5-6.jpg
# ⏭️ Skipping healthy image: C-48-6-3.jpg
# ⏭️ Skipping healthy image: C-48-6-4.jpg
# ⏭️ Skipping healthy image: C-48-7-1.jpg
# ⏭️ Skipping healthy image: C-48-7-7.jpg
# ⏭️ Skipping healthy image: C-4-9-3.jpg
# ⏭️ Skipping healthy image: C-4-9-5.jpg
# ⏭️ Skipping healthy image: C-5-6-1.jpg
# ⏭️ Skipping healthy image: C-5-7-2.jpg
# ⏭️ Skipping healthy image: C-5-9-3.jpg
# ⏭️ Skipping healthy image: C-5-9-4.jpg
# ⏭️ Skipping healthy image: C-6-6-6.jpg
# ⏭️ Skipping healthy image: C-6-7-1.jpg
# ⏭️ Skipping healthy image: C-6-7-2.jpg
# ⏭️ Skipping healthy image: C-6-7-3.jpg
# ⏭️ Skipping healthy image: C-6-9-4.jpg
# ⏭️ Skipping healthy image: C-6-9-5.jpg
# ⏭️ Skipping healthy image: C-8-12-2.jpg
# ⏭️ Skipping healthy image: C-8-12-6.jpg
# ⏭️ Skipping healthy image: C-8-4-4.jpg
# ⏭️ Skipping healthy image: C-8-5-5.jpg
# ⏭️ Skipping healthy image: C-8-6-3.jpg
# ⏭️ Skipping healthy image: C-8-7-1.jpg
# ⏭️ Skipping healthy image: C-9-12-1.jpg
# ⏭️ Skipping healthy image: C-9-1-7.jpg
# ⏭️ Skipping healthy image: C-9-4-5.jpg
# ⏭️ Skipping healthy image: C-9-4-6.jpg
# ⏭️ Skipping healthy image: C-9-5-4.jpg
# ⏭️ Skipping healthy image: C-9-7-2.jpg
# ⏭️ Skipping healthy image: C-9-7-3.jpg
# ⏭️ Skipping healthy image: N-001-03.jpg
# ⏭️ Skipping healthy image: N-026-02.jpg
# ⏭️ Skipping healthy image: N-026-03.jpg
# ⏭️ Skipping healthy image: N-026-04.jpg
# ⏭️ Skipping healthy image: N-040-02.jpg
# ⏭️ Skipping healthy image: N-042-02.jpg
# ⏭️ Skipping healthy image: N-042-03.jpg
# ⏭️ Skipping healthy image: N-042-04.jpg
# ⏭️ Skipping healthy image: N-047-04.jpg
# ⏭️ Skipping healthy image: N-070-04.jpg
# ⏭️ Skipping healthy image: N-077-02.jpg
# ⏭️ Skipping healthy image: N-079-03.jpg
# ⏭️ Skipping healthy image: N-079-04.jpg
# ⏭️ Skipping healthy image: N-083-03.jpg
# ⏭️ Skipping healthy image: N-084-02.jpg
# ⏭️ Skipping healthy image: N-091-02.jpg
# ⏭️ Skipping healthy image: N-091-03.jpg
# ⏭️ Skipping healthy image: N-101-02.jpg
# ⏭️ Skipping healthy image: N-101-05.jpg
# ⏭️ Skipping healthy image: N-108-03.jpg
# ⏭️ Skipping healthy image: N-108-04.jpg
# ⏭️ Skipping healthy image: N-108-05.jpg
# ⏭️ Skipping healthy image: N-109-02.jpg
# ⏭️ Skipping healthy image: N-109-04.jpg
# ⏭️ Skipping healthy image: N-110-02.jpg
# ⏭️ Skipping healthy image: N-112-02.jpg
# ⏭️ Skipping healthy image: N-116-02.jpg
# ⏭️ Skipping healthy image: N-116-03.jpg
# ⏭️ Skipping healthy image: N-127-01.jpg
# ⏭️ Skipping healthy image: N-127-02.jpg
# ⏭️ Skipping healthy image: R-57-02.jpg
# ⏭️ Skipping healthy image: R-33-04.jpg
# ⏭️ Skipping healthy image: R-33-05.jpg
# ⏭️ Skipping healthy image: R-57-04.jpg
# ⏭️ Skipping healthy image: R-57-03.jpg
# ⏭️ Skipping healthy image: R-106-01.jpg
# ⏭️ Skipping healthy image: R-106-02.jpg
# ⏭️ Skipping healthy image: R-106-03.jpg
# ⏭️ Skipping healthy image: R-110-04.jpg
# ⏭️ Skipping healthy image: R-111-04.jpg
# ⏭️ Skipping healthy image: R-113-01.jpg
# ⏭️ Skipping healthy image: R-113-02.jpg
# ⏭️ Skipping healthy image: R-113-03.jpg
# ⏭️ Skipping healthy image: R-113-04.jpg
# ⏭️ Skipping healthy image: R-117-02.jpg
# ⏭️ Skipping healthy image: R-117-03.jpg
# ⏭️ Skipping healthy image: R-117-04.jpg
# ⏭️ Skipping healthy image: R-117-05.jpg
# ⏭️ Skipping healthy image: R-117-06.jpg
# ⏭️ Skipping healthy image: R-118-01.jpg
# ⏭️ Skipping healthy image: R-118-02.jpg
# ⏭️ Skipping healthy image: R-118-03.jpg
# ⏭️ Skipping healthy image: R-118-04.jpg
# ⏭️ Skipping healthy image: R-118-05.jpg
# ⏭️ Skipping healthy image: R-119-02.jpg
# ⏭️ Skipping healthy image: R-120-04.jpg
# ⏭️ Skipping healthy image: R-120-05.jpg
# ⏭️ Skipping healthy image: R-120-06.jpg
# ⏭️ Skipping healthy image: R-120-07.jpg
# ⏭️ Skipping healthy image: R-121-02.jpg
# ⏭️ Skipping healthy image: R-121-04.jpg
# ⏭️ Skipping healthy image: R-121-05.jpg
# ⏭️ Skipping healthy image: R-123-01.jpg
# ⏭️ Skipping healthy image: R-123-05.jpg
# ⏭️ Skipping healthy image: R-124-02.jpg
# ⏭️ Skipping healthy image: R-124-03.jpg
# ⏭️ Skipping healthy image: R-124-04.jpg
# ⏭️ Skipping healthy image: R-124-05.jpg
# ⏭️ Skipping healthy image: R-127-01.jpg
# ⏭️ Skipping healthy image: R-127-02.jpg
# ⏭️ Skipping healthy image: R-127-03.jpg
# ⏭️ Skipping healthy image: R-127-04.jpg
# ⏭️ Skipping healthy image: R-128-01.jpg
# ⏭️ Skipping healthy image: R-128-02.jpg
# ⏭️ Skipping healthy image: R-128-03.jpg
# ⏭️ Skipping healthy image: R-132-06.jpg
# ⏭️ Skipping healthy image: R-132-07.jpg
# ⏭️ Skipping healthy image: R-134-05.jpg
# ⏭️ Skipping healthy image: R-135-03.jpg
# ⏭️ Skipping healthy image: R-135-05.jpg
# ⏭️ Skipping healthy image: R-137-02.jpg
# ⏭️ Skipping healthy image: R-137-03.jpg
# ⏭️ Skipping healthy image: R-138-01.jpg
# ⏭️ Skipping healthy image: R-138-02.jpg
# ⏭️ Skipping healthy image: R-138-03.jpg
# ⏭️ Skipping healthy image: R-138-04.jpg
# ⏭️ Skipping healthy image: R-139-02.jpg
# ⏭️ Skipping healthy image: R-139-03.jpg
# ⏭️ Skipping healthy image: R-139-04.jpg
# ⏭️ Skipping healthy image: R-139-05.jpg
# ⏭️ Skipping healthy image: R-139-06.jpg
# ⏭️ Skipping healthy image: R-142-02.jpg
# ⏭️ Skipping healthy image: R-142-03.jpg
# ⏭️ Skipping healthy image: R-143-01.jpg
# ⏭️ Skipping healthy image: R-143-02.jpg
# ⏭️ Skipping healthy image: R-143-03.jpg
# ⏭️ Skipping healthy image: R-143-04.jpg
# ⏭️ Skipping healthy image: R-143-05.jpg
# ⏭️ Skipping healthy image: R-144-02.jpg
# ⏭️ Skipping healthy image: R-144-03.jpg
# ⏭️ Skipping healthy image: R-144-04.jpg
# ⏭️ Skipping healthy image: R-147-03.jpg
# ⏭️ Skipping healthy image: R-147-04.jpg
# ⏭️ Skipping healthy image: R-147-05.jpg
# ⏭️ Skipping healthy image: R-148-01.jpg
# ⏭️ Skipping healthy image: R-148-02.jpg
# ⏭️ Skipping healthy image: R-148-03.jpg
# ⏭️ Skipping healthy image: R-148-04.jpg
# ⏭️ Skipping healthy image: R-148-05.jpg
# ⏭️ Skipping healthy image: R-148-06.jpg
# ⏭️ Skipping healthy image: R-148-07.jpg
# ⏭️ Skipping healthy image: R-148-08.jpg
# ⏭️ Skipping healthy image: R-148-09.jpg
# ⏭️ Skipping healthy image: R-148-10.jpg
# ⏭️ Skipping healthy image: R-153-03.jpg
# ⏭️ Skipping healthy image: R-153-04.jpg
# ⏭️ Skipping healthy image: R-153-05.jpg
# ⏭️ Skipping healthy image: R-154-05.jpg
# ⏭️ Skipping healthy image: R-154-06.jpg
# ⏭️ Skipping healthy image: R-155-02.jpg
# ⏭️ Skipping healthy image: R-155-03.jpg
# ⏭️ Skipping healthy image: R-155-04.jpg
# ⏭️ Skipping healthy image: R-158-02.jpg
# ⏭️ Skipping healthy image: R-158-03.jpg
# ⏭️ Skipping healthy image: R-158-04.jpg
# ⏭️ Skipping healthy image: R-160-01.jpg
# ⏭️ Skipping healthy image: R-160-02.jpg
# ⏭️ Skipping healthy image: R-160-03.jpg
# ⏭️ Skipping healthy image: R-160-04.jpg
# ⏭️ Skipping healthy image: R-160-05.jpg
# ⏭️ Skipping healthy image: R-161-04.jpg
# ⏭️ Skipping healthy image: R-164-01.jpg
# ⏭️ Skipping healthy image: R-164-02.jpg
# ⏭️ Skipping healthy image: R-164-03.jpg
# ⏭️ Skipping healthy image: R-164-04.jpg
# ⏭️ Skipping healthy image: R-164-05.jpg
# ⏭️ Skipping healthy image: R-164-06.jpg
# ⏭️ Skipping healthy image: R-164-07.jpg
# ⏭️ Skipping healthy image: R-164-08.jpg
# ⏭️ Skipping healthy image: R-164-09.jpg
# ⏭️ Skipping healthy image: R-164-10.jpg
# ⏭️ Skipping healthy image: R-168-03.jpg
# ⏭️ Skipping healthy image: R-170-03.jpg
# ⏭️ Skipping healthy image: R-173-06.jpg
# ⏭️ Skipping healthy image: R-174-05.jpg
# ⏭️ Skipping healthy image: R-174-06.jpg
# ⏭️ Skipping healthy image: R-175-06.jpg
# ⏭️ Skipping healthy image: R-175-07.jpg
# ⏭️ Skipping healthy image: R-177-01.jpg
# ⏭️ Skipping healthy image: R-177-02.jpg
# ⏭️ Skipping healthy image: R-184-06.jpg
# ⏭️ Skipping healthy image: R-190-01.jpg
# ⏭️ Skipping healthy image: R-190-02.jpg
# ⏭️ Skipping healthy image: R-190-03.jpg
# ⏭️ Skipping healthy image: R-190-04.jpg
# ⏭️ Skipping healthy image: R-190-05.jpg
# ⏭️ Skipping healthy image: R-194-05.jpg
# ⏭️ Skipping healthy image: R-199-05.jpg
# ⏭️ Skipping healthy image: R-205-01.jpg
# ⏭️ Skipping healthy image: R-205-02.jpg
# ⏭️ Skipping healthy image: R-205-03.jpg
# ⏭️ Skipping healthy image: R-205-04.jpg
# ⏭️ Skipping healthy image: R-207-01.jpg
# ⏭️ Skipping healthy image: R-207-02.jpg
# ⏭️ Skipping healthy image: R-207-03.jpg
# ⏭️ Skipping healthy image: R-207-04.jpg
# ⏭️ Skipping healthy image: R-212-01.jpg
# ⏭️ Skipping healthy image: R-212-02.jpg
# ⏭️ Skipping healthy image: R-220-03.jpg
# ⏭️ Skipping healthy image: R-221-07.jpg
# ⏭️ Skipping healthy image: R-224-05.jpg
# ⏭️ Skipping healthy image: R-224-06.jpg
# ⏭️ Skipping healthy image: R-227-01.jpg
# ⏭️ Skipping healthy image: R-227-02.jpg
# ⏭️ Skipping healthy image: R-227-03.jpg
# ⏭️ Skipping healthy image: R-227-04.jpg
# ⏭️ Skipping healthy image: R-232-06.jpg
# ⏭️ Skipping healthy image: R-238-04.jpg
# ⏭️ Skipping healthy image: R-240-02.jpg
# ⏭️ Skipping healthy image: R-240-04.jpg
# ⏭️ Skipping healthy image: R-240-05.jpg
# ⏭️ Skipping healthy image: R-245-04.jpg
# ⏭️ Skipping healthy image: R-245-05.jpg
# ⏭️ Skipping healthy image: R-245-06.jpg
# ⏭️ Skipping healthy image: R-245-07.jpg
# ⏭️ Skipping healthy image: R-246-07.jpg
# ⏭️ Skipping healthy image: R-253-01.jpg
# ⏭️ Skipping healthy image: R-253-02.jpg
# ⏭️ Skipping healthy image: R-253-03.jpg
# ⏭️ Skipping healthy image: R-253-04.jpg
# ⏭️ Skipping healthy image: R-253-05.jpg
# ⏭️ Skipping healthy image: R-259-03.jpg
# ⏭️ Skipping healthy image: R-259-11.jpg
# ⏭️ Skipping healthy image: R-260-04.jpg
# ⏭️ Skipping healthy image: R-260-05.jpg
# ⏭️ Skipping healthy image: R-263-08.jpg
# ⏭️ Skipping healthy image: R-271-08.jpg
# ⏭️ Skipping healthy image: R-271-10.jpg
# ⏭️ Skipping healthy image: R-273-05.jpg
# ⏭️ Skipping healthy image: N-257-05.jpg
# ⏭️ Skipping healthy image: N-257-06.jpg
# ⏭️ Skipping healthy image: N-258-01.jpg
# ⏭️ Skipping healthy image: N-259-07.jpg
# ⏭️ Skipping healthy image: N-261-07.jpg
# ⏭️ Skipping healthy image: N-262-02.jpg
# ⏭️ Skipping healthy image: N-262-03.jpg
# ⏭️ Skipping healthy image: N-262-04.jpg
# ⏭️ Skipping healthy image: N-262-05.jpg
# ⏭️ Skipping healthy image: N-264-05.jpg
# ⏭️ Skipping healthy image: N-269-04.jpg
# ⏭️ Skipping healthy image: N-269-08.jpg
# ⏭️ Skipping healthy image: N-271-01.jpg
# ⏭️ Skipping healthy image: N-271-02.jpg
# ⏭️ Skipping healthy image: N-271-03.jpg
# ⏭️ Skipping healthy image: N-271-04.jpg
# ⏭️ Skipping healthy image: N-271-05.jpg
# ⏭️ Skipping healthy image: N-271-06.jpg
# ⏭️ Skipping healthy image: N-271-07.jpg
# ⏭️ Skipping healthy image: N-271-08.jpg
# ⏭️ Skipping healthy image: N-276-01.jpg
# ⏭️ Skipping healthy image: N-276-05.jpg
# ⏭️ Skipping healthy image: N-276-06.jpg
# ⏭️ Skipping healthy image: N-276-07.jpg
# ⏭️ Skipping healthy image: N-276-08.jpg
# ⏭️ Skipping healthy image: N-276-09.jpg
# ⏭️ Skipping healthy image: N-280-01.jpg
# ⏭️ Skipping healthy image: N-291-07.jpg
# ⏭️ Skipping healthy image: N-299-01.jpg
# ⏭️ Skipping healthy image: N-302-01.jpg
# ⏭️ Skipping healthy image: N-302-07.jpg
# ⏭️ Skipping healthy image: N-302-08.jpg
# ⏭️ Skipping healthy image: N-303-07.jpg
# ⏭️ Skipping healthy image: N-350-05.jpg
# ⏭️ Skipping healthy image: N-351-01.jpg
# ⏭️ Skipping healthy image: N-351-03.jpg
# ⏭️ Skipping healthy image: N-351-04.jpg
# ⏭️ Skipping healthy image: N-351-05.jpg
# ⏭️ Skipping healthy image: N-351-06.jpg
# ⏭️ Skipping healthy image: N-351-07.jpg
# ⏭️ Skipping healthy image: N-351-08.jpg
# ⏭️ Skipping healthy image: N-354-01.jpg
# No. of Healthy images, which were skipped for mask formation by SAM model: 729

# %% [markdown]
# ##Final Metrics of SAM model on 3000 images

# %%
#Final model-level evaluation
ious = [m["iou"] for m in all_metrics]
dices = [m["dice"] for m in all_metrics]
accs = [m["accuracy"] for m in all_metrics]

print("\n📊 Final Evaluation of SAM:")
print(f"✅ Total images evaluated: {len(ious)}")
print(f"📉 Mean IoU: {np.mean(ious):.4f}")
print(f"📉 Mean Dice: {np.mean(dices):.4f}")
print(f"📉 Mean Pixel Accuracy: {np.mean(accs):.4f}")
print(f"❌ Skipped images: {skipped}")
# Out:
# 📊 Final Evaluation of SAM:
# ✅ Total images evaluated: 2271
# 📉 Mean IoU: 0.6139
# 📉 Mean Dice: 0.7405
# 📉 Mean Pixel Accuracy: 0.8044
# ❌ Skipped images: 729

# %% [markdown]
# ##To view "Mask by SAM" and "Ground Truth Mask"
# Downloaded .ipynb just after completion:
# Screen-Recording:
